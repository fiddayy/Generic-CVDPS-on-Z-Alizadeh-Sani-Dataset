# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, LSTM, GRU
from sklearn.utils import resample
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load the dataset
df = pd.read_csv('ZAlizadeh.csv')
df
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ...    K   Na    WBC Lymph Neut  PLT EF-TTE  Region RWMA  \
# 0            0   0  ...  4.7  141   5700    39   52  261     50            0
# 1            0   0  ...  4.7  156   7700    38   55  165     40            4
# 2            0   0  ...  4.7  139   7400    38   60  230     40            2
# 3            0   0  ...  4.4  142  13000    18   72  742     55            0
# 4            0   0  ...  4.0  140   9200    55   39  274     50            0
# ..         ...  ..  ...  ...  ...    ...   ...  ...  ...    ...          ...
# 298          0   0  ...  4.8  146   8500    34   58  251     45            0
# 299          0   0  ...  4.0  139  11400    16   80  377     40            0
# 300          0   1  ...  4.0  140   9000    35   55  279     55            0
# 301          0   0  ...  3.8  141   3800    48   40  208     55            0
# 302          0   0  ...  4.4  147   6000    32   55  302     55            0
#
#         VHD    Cath
# 0         N     Cad
# 1         N     Cad
# 2      mild     Cad
# 3    Severe  Normal
# 4    Severe  Normal
# ..      ...     ...
# 298       N     Cad
# 299    mild  Normal
# 300       N  Normal
# 301       N  Normal
# 302       N     Cad
#
# [303 rows x 55 columns]

# %%
df.isnull().sum()
# Out:
# Age                      0
# Weight                   0
# Length                   0
# Sex                      0
# BMI                      0
# DM                       0
# HTN                      0
# Current Smoker           0
# EX-Smoker                0
# FH                       0
# Obesity                  0
# CRF                      0
# CVA                      0
# Airway disease           0
# Thyroid Disease          0
# CHF                      0
# DLP                      0
# BP                       0
# PR                       0
# Edema                    0
# Weak Peripheral Pulse    0
# Lung rales               0
# Systolic Murmur          0
# Diastolic Murmur         0
# Typical Chest Pain       0
# Dyspnea                  0
# Function Class           0
# Atypical                 0
# Nonanginal               0
# Exertional CP            0
# LowTH Ang                0
# Q Wave                   0
# St Elevation             0
# St Depression            0
# Tinversion               0
# LVH                      0
# Poor R Progression       0
# FBS                      0
# CR                       0
# TG                       0
# LDL                      0
# HDL                      0
# BUN                      0
# ESR                      0
# HB                       0
# K                        0
# Na                       0
# WBC                      0
# Lymph                    0
# Neut                     0
# PLT                      0
# EF-TTE                   0
# Region RWMA              0
# VHD                      0
# Cath                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    303 non-null    int64
#  1   Weight                 303 non-null    int64
#  2   Length                 303 non-null    int64
#  3   Sex                    303 non-null    object
#  4   BMI                    303 non-null    float64
#  5   DM                     303 non-null    int64
#  6   HTN                    303 non-null    int64
#  7   Current Smoker         303 non-null    int64
#  8   EX-Smoker              303 non-null    int64
#  9   FH                     303 non-null    int64
#  10  Obesity                303 non-null    object
#  11  CRF                    303 non-null    object
#  12  CVA                    303 non-null    object
#  13  Airway disease         303 non-null    object
#  14  Thyroid Disease        303 non-null    object
#  15  CHF                    303 non-null    object
#  16  DLP                    303 non-null    object
#  17  BP                     303 non-null    int64
#  18  PR                     303 non-null    int64
#  19  Edema                  303 non-null    int64
#  20  Weak Peripheral Pulse  303 non-null    object
#  21  Lung rales             303 non-null    object
#  22  Systolic Murmur        303 non-null    object
#  23  Diastolic Murmur       303 non-null    object
#  24  Typical Chest Pain     303 non-null    int64
#  25  Dyspnea                303 non-null    object
#  26  Function Class         303 non-null    int64
#  27  Atypical               303 non-null    object
#  28  Nonanginal             303 non-null    object
#  29  Exertional CP          303 non-null    object
#  30  LowTH Ang              303 non-null    object
#  31  Q Wave                 303 non-null    int64
#  32  St Elevation           303 non-null    int64
#  33  St Depression          303 non-null    int64
#  34  Tinversion             303 non-null    int64
#  35  LVH                    303 non-null    object
#  36  Poor R Progression     303 non-null    object
#  37  FBS                    303 non-null    int64
#  38  CR                     303 non-null    float64
#  39  TG                     303 non-null    int64
#  40  LDL                    303 non-null    int64
#  41  HDL                    303 non-null    float64
#  42  BUN                    303 non-null    int64
#  43  ESR                    303 non-null    int64
#  44  HB                     303 non-null    float64
#  45  K                      303 non-null    float64
#  46  Na                     303 non-null    int64
#  47  WBC                    303 non-null    int64
#  48  Lymph                  303 non-null    int64
#  49  Neut                   303 non-null    int64
#  50  PLT                    303 non-null    int64
#  51  EF-TTE                 303 non-null    int64
#  52  Region RWMA            303 non-null    int64
#  53  VHD                    303 non-null    object
#  54  Cath                   303 non-null    object
# dtypes: float64(5), int64(29), object(21)
# memory usage: 130.3+ KB

# %%
df.describe()
# Out:
#               Age      Weight      Length         BMI          DM         HTN  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    58.897690   73.831683  164.716172   27.248339    0.297030    0.590759
# std     10.392278   11.987358    9.327661    4.098865    0.457706    0.492507
# min     30.000000   48.000000  140.000000   18.115413    0.000000    0.000000
# 25%     51.000000   65.000000  158.000000   24.514380    0.000000    0.000000
# 50%     58.000000   74.000000  165.000000   26.775510    0.000000    1.000000
# 75%     66.000000   81.000000  171.000000   29.411765    1.000000    1.000000
# max     86.000000  120.000000  188.000000   40.900658    1.000000    1.000000
#
#        Current Smoker   EX-Smoker          FH          BP  ...         ESR  \
# count      303.000000  303.000000  303.000000  303.000000  ...  303.000000
# mean         0.207921    0.033003    0.158416  129.554455  ...   19.462046
# std          0.406491    0.178941    0.365734   18.938105  ...   15.936475
# min          0.000000    0.000000    0.000000   90.000000  ...    1.000000
# 25%          0.000000    0.000000    0.000000  120.000000  ...    9.000000
# 50%          0.000000    0.000000    0.000000  130.000000  ...   15.000000
# 75%          0.000000    0.000000    0.000000  140.000000  ...   26.000000
# max          1.000000    1.000000    1.000000  190.000000  ...   90.000000
#
#                HB           K          Na           WBC       Lymph  \
# count  303.000000  303.000000  303.000000    303.000000  303.000000
# mean    13.153465    4.230693  140.996700   7562.046205   32.399340
# std      1.610452    0.458202    3.807885   2413.739323    9.972592
# min      8.900000    3.000000  128.000000   3700.000000    7.000000
# 25%     12.200000    3.900000  139.000000   5800.000000   26.000000
# 50%     13.200000    4.200000  141.000000   7100.000000   32.000000
# 75%     14.200000    4.500000  143.000000   8800.000000   39.000000
# max     17.600000    6.600000  156.000000  18000.000000   60.000000
#
#              Neut         PLT      EF-TTE  Region RWMA
# count  303.000000  303.000000  303.000000   303.000000
# mean    60.148515  221.488449   47.231023     0.620462
# std     10.182493   60.796199    8.927194     1.132531
# min     32.000000   25.000000   15.000000     0.000000
# 25%     52.500000  183.500000   45.000000     0.000000
# 50%     60.000000  210.000000   50.000000     0.000000
# 75%     67.000000  250.000000   55.000000     1.000000
# max     89.000000  742.000000   60.000000     4.000000
#
# [8 rows x 34 columns]

# %%
df = df.dropna(axis=0)

# %%
df.shape
# Out:
# (303, 55)

# %%
df = df.dropna(axis=1)

# %%
df
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ...    K   Na    WBC Lymph Neut  PLT EF-TTE  Region RWMA  \
# 0            0   0  ...  4.7  141   5700    39   52  261     50            0
# 1            0   0  ...  4.7  156   7700    38   55  165     40            4
# 2            0   0  ...  4.7  139   7400    38   60  230     40            2
# 3            0   0  ...  4.4  142  13000    18   72  742     55            0
# 4            0   0  ...  4.0  140   9200    55   39  274     50            0
# ..         ...  ..  ...  ...  ...    ...   ...  ...  ...    ...          ...
# 298          0   0  ...  4.8  146   8500    34   58  251     45            0
# 299          0   0  ...  4.0  139  11400    16   80  377     40            0
# 300          0   1  ...  4.0  140   9000    35   55  279     55            0
# 301          0   0  ...  3.8  141   3800    48   40  208     55            0
# 302          0   0  ...  4.4  147   6000    32   55  302     55            0
#
#         VHD    Cath
# 0         N     Cad
# 1         N     Cad
# 2      mild     Cad
# 3    Severe  Normal
# 4    Severe  Normal
# ..      ...     ...
# 298       N     Cad
# 299    mild  Normal
# 300       N  Normal
# 301       N  Normal
# 302       N     Cad
#
# [303 rows x 55 columns]

# %%
vhd = {"N": 0, "mild": 1, "Moderate": 2, "Severe": 3}
sex = {"Male": "Male", "Fmale": "Female"}

df['VHD'] = df['VHD'].map(vhd)
df['Sex'] = df['Sex'].map(sex)

df.replace('N', 0, inplace=True)
df.replace('Y', 1, inplace=True)

cath = {"Cad": 1, "Normal":0}
df['Cath'] = df['Cath'].map(cath)

df
# Out:
#      Age  Weight  Length     Sex        BMI  DM  HTN  Current Smoker  \
# 0     53      90     175    Male  29.387755   0    1               1
# 1     67      70     157  Female  28.398718   0    1               0
# 2     54      54     164    Male  20.077335   0    0               1
# 3     66      67     158  Female  26.838648   0    1               0
# 4     50      87     153  Female  37.165193   0    1               0
# ..   ...     ...     ...     ...        ...  ..  ...             ...
# 298   58      84     168    Male  29.761905   0    0               0
# 299   55      64     152  Female  27.700831   0    0               0
# 300   48      77     160  Female  30.078125   0    1               0
# 301   57      90     159  Female  35.599858   1    0               0
# 302   56      85     170  Female  29.411765   0    1               1
#
#      EX-Smoker  FH  ...    K   Na    WBC  Lymph  Neut  PLT  EF-TTE  \
# 0            0   0  ...  4.7  141   5700     39    52  261      50
# 1            0   0  ...  4.7  156   7700     38    55  165      40
# 2            0   0  ...  4.7  139   7400     38    60  230      40
# 3            0   0  ...  4.4  142  13000     18    72  742      55
# 4            0   0  ...  4.0  140   9200     55    39  274      50
# ..         ...  ..  ...  ...  ...    ...    ...   ...  ...     ...
# 298          0   0  ...  4.8  146   8500     34    58  251      45
# 299          0   0  ...  4.0  139  11400     16    80  377      40
# 300          0   1  ...  4.0  140   9000     35    55  279      55
# 301          0   0  ...  3.8  141   3800     48    40  208      55
# 302          0   0  ...  4.4  147   6000     32    55  302      55
#
#      Region RWMA  VHD  Cath
# 0              0    0     1
# 1              4    0     1
# 2              2    1     1
# 3              0    3     0
# 4              0    3     0
# ..           ...  ...   ...
# 298            0    0     1
# 299            0    1     0
# 300            0    0     0
# 301            0    0     0
# 302            0    0     1
#
# [303 rows x 55 columns]

# %%
sex = {"Male": 1, "Female": 0}
df['Sex'] = df['Sex'].map(sex)

# %%
df
# Out:
#      Age  Weight  Length  Sex        BMI  DM  HTN  Current Smoker  EX-Smoker  \
# 0     53      90     175    1  29.387755   0    1               1          0
# 1     67      70     157    0  28.398718   0    1               0          0
# 2     54      54     164    1  20.077335   0    0               1          0
# 3     66      67     158    0  26.838648   0    1               0          0
# 4     50      87     153    0  37.165193   0    1               0          0
# ..   ...     ...     ...  ...        ...  ..  ...             ...        ...
# 298   58      84     168    1  29.761905   0    0               0          0
# 299   55      64     152    0  27.700831   0    0               0          0
# 300   48      77     160    0  30.078125   0    1               0          0
# 301   57      90     159    0  35.599858   1    0               0          0
# 302   56      85     170    0  29.411765   0    1               1          0
#
#      FH  ...    K   Na    WBC  Lymph  Neut  PLT  EF-TTE  Region RWMA  VHD  \
# 0     0  ...  4.7  141   5700     39    52  261      50            0    0
# 1     0  ...  4.7  156   7700     38    55  165      40            4    0
# 2     0  ...  4.7  139   7400     38    60  230      40            2    1
# 3     0  ...  4.4  142  13000     18    72  742      55            0    3
# 4     0  ...  4.0  140   9200     55    39  274      50            0    3
# ..   ..  ...  ...  ...    ...    ...   ...  ...     ...          ...  ...
# 298   0  ...  4.8  146   8500     34    58  251      45            0    0
# 299   0  ...  4.0  139  11400     16    80  377      40            0    1
# 300   1  ...  4.0  140   9000     35    55  279      55            0    0
# 301   0  ...  3.8  141   3800     48    40  208      55            0    0
# 302   0  ...  4.4  147   6000     32    55  302      55            0    0
#
#      Cath
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
# ..    ...
# 298     1
# 299     0
# 300     0
# 301     0
# 302     1
#
# [303 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 0 to 302
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    303 non-null    int64
#  1   Weight                 303 non-null    int64
#  2   Length                 303 non-null    int64
#  3   Sex                    303 non-null    int64
#  4   BMI                    303 non-null    float64
#  5   DM                     303 non-null    int64
#  6   HTN                    303 non-null    int64
#  7   Current Smoker         303 non-null    int64
#  8   EX-Smoker              303 non-null    int64
#  9   FH                     303 non-null    int64
#  10  Obesity                303 non-null    int64
#  11  CRF                    303 non-null    int64
#  12  CVA                    303 non-null    int64
#  13  Airway disease         303 non-null    int64
#  14  Thyroid Disease        303 non-null    int64
#  15  CHF                    303 non-null    int64
#  16  DLP                    303 non-null    int64
#  17  BP                     303 non-null    int64
#  18  PR                     303 non-null    int64
#  19  Edema                  303 non-null    int64
#  20  Weak Peripheral Pulse  303 non-null    int64
#  21  Lung rales             303 non-null    int64
#  22  Systolic Murmur        303 non-null    int64
#  23  Diastolic Murmur       303 non-null    int64
#  24  Typical Chest Pain     303 non-null    int64
#  25  Dyspnea                303 non-null    int64
#  26  Function Class         303 non-null    int64
#  27  Atypical               303 non-null    int64
#  28  Nonanginal             303 non-null    int64
#  29  Exertional CP          303 non-null    int64
#  30  LowTH Ang              303 non-null    int64
#  31  Q Wave                 303 non-null    int64
#  32  St Elevation           303 non-null    int64
#  33  St Depression          303 non-null    int64
#  34  Tinversion             303 non-null    int64
#  35  LVH                    303 non-null    int64
#  36  Poor R Progression     303 non-null    int64
#  37  FBS                    303 non-null    int64
#  38  CR                     303 non-null    float64
#  39  TG                     303 non-null    int64
#  40  LDL                    303 non-null    int64
#  41  HDL                    303 non-null    float64
#  42  BUN                    303 non-null    int64
#  43  ESR                    303 non-null    int64
#  44  HB                     303 non-null    float64


# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (303, 55)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X = df.drop('Cath', axis=1)  # Features
y = df['Cath']  # Target variable

# %%
# 1. Load and preprocess the data
# Assuming you have your data in the X and y variables

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
input_shape = (X_train.shape[1], 1)
input_shape_cnn = (X_train.shape[1], 1)

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=11, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.25))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Dense(1, activation='sigmoid'))  # Output layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
# Train the individual models
cnn_model = build_cnn_model(input_shape)
cnn_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test),
             callbacks=[callback_early_stopping, callback_checkpoint])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 183ms/step - loss: 0.7348 - accuracy: 0.6368 - val_loss: 0.5573 - val_accuracy: 0.7802
# Epoch 2/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.5880 - accuracy: 0.7264 - val_loss: 0.5359 - val_accuracy: 0.8352
# Epoch 3/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5199 - accuracy: 0.7736 - val_loss: 0.5578 - val_accuracy: 0.8791
# Epoch 4/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4347 - accuracy: 0.8160 - val_loss: 0.5820 - val_accuracy: 0.8242
# Epoch 5/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4143 - accuracy: 0.8302 - val_loss: 0.6060 - val_accuracy: 0.7253
# Epoch 6/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3930 - accuracy: 0.8160 - val_loss: 0.5617 - val_accuracy: 0.8352
# Epoch 7/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.3856 - accuracy: 0.8302 - val_loss: 0.5161 - val_accuracy: 0.8681
# Epoch 8/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.3834 - accuracy: 0.8491 - val_loss: 0.5031 - val_accuracy: 0.8791
# Epoch 9/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3502 - accuracy: 0.8538 - val_loss: 0.5216 - val_accuracy: 0.8681
# Epoch 10/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3161 - accuracy: 0.8868 - val_loss: 0.5258 - val_accuracy: 0.8242
# Epoch 11/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.3489 - accuracy: 0.8443 - val_loss: 0.4912 - val_accuracy: 0.8462
# Epoch 12/100
# 5/5 [==============================] - 0s 74ms/step - loss: 0.3150 - accuracy: 0.8538 - val_loss: 0.4504 - val_accuracy: 0.8681
# Epoch 13/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3250 - accuracy: 0.8443 - val_loss: 0.4284 - val_accuracy: 0.8462
# Epoch 14/100
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2900 - accuracy: 0.8774 - val_loss: 0.4197 - val_accuracy: 0.8352
# Epoch 15/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2601 - accuracy: 0.9198 - val_loss: 0.4345 - val_accuracy: 0.7802
# Epoch 16/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2192 - accuracy: 0.9245 - val_loss: 0.4342 - val_accuracy: 0.7582
# Epoch 17/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2332 - accuracy: 0.9151 - val_loss: 0.4253 - val_accuracy: 0.7692
# Epoch 18/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.2273 - accuracy: 0.9292 - val_loss: 0.4168 - val_accuracy: 0.7692
# Epoch 19/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1735 - accuracy: 0.9434 - val_loss: 0.4249 - val_accuracy: 0.7582
# Epoch 20/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1849 - accuracy: 0.9340 - val_loss: 0.4228 - val_accuracy: 0.7473
# Epoch 21/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1868 - accuracy: 0.9481 - val_loss: 0.4188 - val_accuracy: 0.7692
# Epoch 22/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1675 - accuracy: 0.9434 - val_loss: 0.4381 - val_accuracy: 0.7912
# Epoch 23/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1695 - accuracy: 0.9292 - val_loss: 0.4521 - val_accuracy: 0.7802
# Epoch 24/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1594 - accuracy: 0.9528 - val_loss: 0.4233 - val_accuracy: 0.7912
# Epoch 25/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1781 - accuracy: 0.9198 - val_loss: 0.3930 - val_accuracy: 0.8022
# Epoch 26/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.1649 - accuracy: 0.9245 - val_loss: 0.3771 - val_accuracy: 0.8022
# Epoch 27/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1768 - accuracy: 0.9104 - val_loss: 0.3902 - val_accuracy: 0.7692
# Epoch 28/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1142 - accuracy: 0.9575 - val_loss: 0.4096 - val_accuracy: 0.7473
# Epoch 29/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1118 - accuracy: 0.9764 - val_loss: 0.4243 - val_accuracy: 0.7253
# Epoch 30/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0975 - accuracy: 0.9764 - val_loss: 0.4219 - val_accuracy: 0.7582
# Epoch 31/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0792 - accuracy: 0.9858 - val_loss: 0.4121 - val_accuracy: 0.7582
# Epoch 32/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0878 - accuracy: 0.9811 - val_loss: 0.4158 - val_accuracy: 0.7692
# Epoch 33/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0837 - accuracy: 0.9811 - val_loss: 0.4156 - val_accuracy: 0.7692
# Epoch 34/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0714 - accuracy: 0.9811 - val_loss: 0.4059 - val_accuracy: 0.7912
# Epoch 35/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0742 - accuracy: 0.9764 - val_loss: 0.3915 - val_accuracy: 0.8022
# Epoch 36/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0803 - accuracy: 0.9811 - val_loss: 0.3936 - val_accuracy: 0.8132

# %%
# 8. Evaluate the model
test_loss, test_accuracy = cnn_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3771 - accuracy: 0.8022
# Test Loss: 0.3771
# Test Accuracy: 0.8022

# %%
# Make predictions
y_pred = cnn_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 3/3 [==============================] - 0s 7ms/step
# Confusion Matrix:
# [[10 15]
#  [ 3 63]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.40      0.53        25
#            1       0.81      0.95      0.88        66
#
#     accuracy                           0.80        91
#    macro avg       0.79      0.68      0.70        91
# weighted avg       0.80      0.80      0.78        91

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(11, return_sequences=True, input_shape=input_shape))
    model.add(LSTM(32, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(32))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
lstm_model = build_lstm_model(input_shape)
lstm_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test),
              callbacks=[callback_early_stopping, callback_checkpoint])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 17s 914ms/step - loss: 0.6752 - accuracy: 0.6085 - val_loss: 0.6747 - val_accuracy: 0.7253
# Epoch 2/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.6137 - accuracy: 0.7075 - val_loss: 0.6131 - val_accuracy: 0.7253
# Epoch 3/100
# 5/5 [==============================] - 1s 173ms/step - loss: 0.5677 - accuracy: 0.7075 - val_loss: 0.5415 - val_accuracy: 0.7253
# Epoch 4/100
# 5/5 [==============================] - 1s 141ms/step - loss: 0.5621 - accuracy: 0.7075 - val_loss: 0.5449 - val_accuracy: 0.7253
# Epoch 5/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.5580 - accuracy: 0.7075 - val_loss: 0.5497 - val_accuracy: 0.7253
# Epoch 6/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.5579 - accuracy: 0.7075 - val_loss: 0.5419 - val_accuracy: 0.7253
# Epoch 7/100
# 5/5 [==============================] - 1s 175ms/step - loss: 0.5522 - accuracy: 0.7075 - val_loss: 0.5407 - val_accuracy: 0.7253
# Epoch 8/100
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5440 - accuracy: 0.7075 - val_loss: 0.5366 - val_accuracy: 0.7253
# Epoch 9/100
# 5/5 [==============================] - 1s 148ms/step - loss: 0.5444 - accuracy: 0.7075 - val_loss: 0.5410 - val_accuracy: 0.7253
# Epoch 10/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.5405 - accuracy: 0.7075 - val_loss: 0.5473 - val_accuracy: 0.7253
# Epoch 11/100
# 5/5 [==============================] - 1s 142ms/step - loss: 0.5379 - accuracy: 0.7075 - val_loss: 0.5391 - val_accuracy: 0.7253
# Epoch 12/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.5332 - accuracy: 0.7075 - val_loss: 0.5345 - val_accuracy: 0.7253
# Epoch 13/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.5258 - accuracy: 0.7075 - val_loss: 0.5491 - val_accuracy: 0.7253
# Epoch 14/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.5256 - accuracy: 0.7075 - val_loss: 0.5514 - val_accuracy: 0.7253
# Epoch 15/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.5190 - accuracy: 0.7123 - val_loss: 0.5449 - val_accuracy: 0.7253
# Epoch 16/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.5177 - accuracy: 0.7123 - val_loss: 0.5488 - val_accuracy: 0.7253
# Epoch 17/100
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5198 - accuracy: 0.7028 - val_loss: 0.5290 - val_accuracy: 0.7253
# Epoch 18/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.5341 - accuracy: 0.6887 - val_loss: 0.5367 - val_accuracy: 0.7253
# Epoch 19/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.5264 - accuracy: 0.6981 - val_loss: 0.5611 - val_accuracy: 0.7253
# Epoch 20/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.5327 - accuracy: 0.7170 - val_loss: 0.5586 - val_accuracy: 0.7253
# Epoch 21/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.5213 - accuracy: 0.6981 - val_loss: 0.5645 - val_accuracy: 0.7253
# Epoch 22/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.5144 - accuracy: 0.6934 - val_loss: 0.5554 - val_accuracy: 0.7253
# Epoch 23/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.5024 - accuracy: 0.7170 - val_loss: 0.5452 - val_accuracy: 0.7253
# Epoch 24/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.5040 - accuracy: 0.6981 - val_loss: 0.5393 - val_accuracy: 0.7253
# Epoch 25/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.4986 - accuracy: 0.7170 - val_loss: 0.5705 - val_accuracy: 0.7253
# Epoch 26/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.4831 - accuracy: 0.7264 - val_loss: 0.5735 - val_accuracy: 0.7253
# Epoch 27/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.4880 - accuracy: 0.7264 - val_loss: 0.6026 - val_accuracy: 0.7253

# %%
# 8. Evaluate the model
test_loss, test_accuracy = lstm_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5290 - accuracy: 0.7253
# Test Loss: 0.5290
# Test Accuracy: 0.7253

# %%
# Make predictions
y_pred = lstm_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 3/3 [==============================] - 3s 35ms/step
# Confusion Matrix:
# [[ 0 25]
#  [ 0 66]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        25
#            1       0.73      1.00      0.84        66
#
#     accuracy                           0.73        91
#    macro avg       0.36      0.50      0.42        91
# weighted avg       0.53      0.73      0.61        91
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_gru_model(input_shape):
    model = Sequential()
    model.add(GRU
# 5/5 [==============================] - 1s 281ms/step - loss: 0.3355 - accuracy: 0.8255 - val_loss: 0.5783 - val_accuracy: 0.6813
# Epoch 44/100
# 5/5 [==============================] - 1s 289ms/step - loss: 0.3589 - accuracy: 0.8208 - val_loss: 0.6050 - val_accuracy: 0.6593
# Epoch 45/100
# 5/5 [==============================] - 1s 293ms/step - loss: 0.3166 - accuracy: 0.8632 - val_loss: 0.6059 - val_accuracy: 0.7033
# Epoch 46/100
# 5/5 [==============================] - 1s 279ms/step - loss: 0.2999 - accuracy: 0.8538 - val_loss: 0.5859 - val_accuracy: 0.7033
# Epoch 47/100
# 5/5 [==============================] - 1s 277ms/step - loss: 0.2897 - accuracy: 0.8774 - val_loss: 0.5695 - val_accuracy: 0.7253
# Epoch 48/100
# 5/5 [==============================] - 1s 301ms/step - loss: 0.3147 - accuracy: 0.8396 - val_loss: 0.5817 - val_accuracy: 0.7473
# Epoch 49/100
# 5/5 [==============================] - 2s 307ms/step - loss: 0.2569 - accuracy: 0.9009 - val_loss: 0.6067 - val_accuracy: 0.7143
# Epoch 50/100
# 5/5 [==============================] - 1s 279ms/step - loss: 0.2583 - accuracy: 0.8821 - val_loss: 0.6154 - val_accuracy: 0.7253
# Epoch 51/100
# 5/5 [==============================] - 1s 279ms/step - loss: 0.2791 - accuracy: 0.8868 - val_loss: 0.6367 - val_accuracy: 0.7033
# Epoch 52/100
# 5/5 [==============================] - 1s 286ms/step - loss: 0.2509 - accuracy: 0.8915 - val_loss: 0.7081 - val_accuracy: 0.7033

# %%
# 8. Evaluate the model
test_loss, test_accuracy = gru_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5538 - accuracy: 0.7363
# Test Loss: 0.5538
# Test Accuracy: 0.7363

# %%
# Make predictions
y_pred = gru_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 3/3 [==============================] - 3s 59ms/step
# Confusion Matrix:
# [[ 3 22]
#  [ 2 64]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.12      0.20        25
#            1       0.74      0.97      0.84        66
#
#     accuracy                           0.74        91
#    macro avg       0.67      0.54      0.52        91
# weighted avg       0.70      0.74      0.67        91

# %%
# Make predictions using individual models
cnn_predictions = (cnn_model.predict(X_test) > 0.5).astype("int32")
lstm_predictions = (lstm_model.predict(X_test) > 0.5).astype("int32")
gru_predictions = (gru_model.predict(X_test) > 0.5).astype("int32")
# Out:
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 36ms/step
# 3/3 [==============================] - 0s 61ms/step

# %%
# Combine predictions using a majority voting ensemble
ensemble_predictions = np.mean([cnn_predictions, lstm_predictions, gru_predictions], axis=0) >= 0.5
ensemble_predictions = ensemble_predictions.astype("int32")

# %%
# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, ensemble_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.7363

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, ensemble_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, ensemble_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, ensemble_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Confusion Matrix:
# [[ 1 24]
#  [ 0 66]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.04      0.08        25
#            1       0.73      1.00      0.85        66
#
#     accuracy                           0.74        91
#    macro avg       0.87      0.52      0.46        91
# weighted avg       0.81      0.74      0.63        91
#
# Ensemble Accuracy: 0.7363

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.utils import resample
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.model_selection import cross_val_score

# %%
# List of base models

lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

svm_l_model = SVC(kernel="linear")
svm_l_model.fit(X_train, y_train)

svm_p_model = SVC(kernel="poly")
svm_p_model.fit(X_train, y_train)

svm_r_model = SVC(kernel="rbf")
svm_r_model.fit(X_train, y_train)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)


knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)

gb_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_model.fit(X_train, y_train)

ab_model = AdaBoostClassifier(n_estimators=100, random_state=42)
ab_model.fit(X_train, y_train)

xgb_model = XGBClassifier(n_estimators=100, random_state=42)
xgb_model.fit(X_train, y_train)

gpc_model = GaussianProcessClassifier(random_state=42)
gpc_model.fit(X_train, y_train)
# Out:
# GaussianProcessClassifier(random_state=42)

# %%
lr_predictions = lr_model.predict(X_test)
svm_l_predictions = svm_l_model.predict(X_test)
svm_p_predictions = svm_p_model.predict(X_test)
svm_r_predictions = svm_r_model.predict(X_test)
rf_predictions = rf_model.predict(X_test)
knn_predictions = knn_model.predict(X_test)
gb_predictions = gb_model.predict(X_test)
ab_predictions = ab_model.predict(X_test)
xgb_predictions = xgb_model.predict(X_test)
gpc_predictions = gpc_model.predict(X_test)

# %%
# Combine predictions using ensemble (Voting Classifier)
ensemble_predictions = np.column_stack((cnn_predictions, lstm_predictions, gru_predictions, lr_predictions, 
                                        svm_l_predictions, svm_p_predictions, svm_r_predictions, 
                                        rf_predictions, knn_predictions, gb_predictions, 
                                        ab_predictions, xgb_predictions, gpc_predictions))

# %%
# Perform majority voting to get the final prediction
final_predictions = np.mean(ensemble_predictions, axis=1) >= 0.5
final_predictions = final_predictions.astype("int32")

# %%
# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.8462

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, final_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, final_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Confusion Matrix:
# [[14 11]
#  [ 3 63]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.56      0.67        25
#            1       0.85      0.95      0.90        66
#
#     accuracy                           0.85        91
#    macro avg       0.84      0.76      0.78        91
# weighted avg       0.84      0.85      0.84        91
#
# Ensemble Accuracy: 0.8462

# %%
# Combine predictions using ensemble (Voting Classifier)
ensemble_predictions = np.column_stack((cnn_predictions, lstm_predictions, gru_predictions, svm_r_predictions, 
                                        rf_predictions, knn_predictions, gb_predictions, 
                                        xgb_predictions, gpc_predictions))

# %%
# Perform majority voting to get the final prediction
final_predictions = np.mean(ensemble_predictions, axis=1) >= 0.5
final_predictions = final_predictions.astype("int32")

# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, final_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, final_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.8681
# Confusion Matrix:
# [[15 10]
#  [ 2 64]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.60      0.71        25
#            1       0.86      0.97      0.91        66
#
#     accuracy                           0.87        91
#    macro avg       0.87      0.78      0.81        91
# weighted avg       0.87      0.87      0.86        91
#
# Ensemble Accuracy: 0.8681
